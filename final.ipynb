# %% [markdown]
# <a href="https://colab.research.google.com/github/Alinasaghir/Email-SMS-spam-classifier/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# mount google drive

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# importing and downloading yolov8

# %%
# !pip install ultralytics

import os

from ultralytics import YOLO
model = YOLO("yolov8n.pt")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.1/910.1 kB 23.4 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 107MB/s]

# %% [markdown]
# extracting zip

# %%
# !unzip -q test.zip -d /content/datasets

# %% [markdown]
# training model on epochs=3 because it takes alot of time

# %%
results = model.train(data="data.yaml", epochs=3)
# Out:
# Ultralytics 8.3.62 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Analyze results and trained images in runs folder
